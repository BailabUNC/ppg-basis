# %%
# %load_ext profila

# %%
from ppg_basis import ppgExtractor
from ppg_basis import model
from ppg_basis.utils.generator_utils import pp_interval_generator
import matplotlib.pyplot as plt
from ppg_basis import ppgGenerator
from sensor_core import StorageManager as sm

# %%
# %%profila
#
# filepath1 = 'serial/serial_white1_1.sqlite3'
# filepath2 = 'serial/serial_black1_1.sqlite3'
#
# redw = sm.load_serial_channel(filepath=filepath1,
#                               key='red')
# irw = sm.load_serial_channel(filepath=filepath1,
#                              key='infrared')
# # Extract pigmented data
# redb = sm.load_serial_channel(filepath=filepath2,
#                               key='red')
# irb = sm.load_serial_channel(filepath=filepath2,
#                              key='infrared')

# %%
# %%profila
#
# ppgExt = ppgExtractor(
#     irw[0::round(len(irw)/2)],
#     60,
#     60,
#     0,
#     2,
#     "gaussian"
# )
#
# extracted_ppg = ppgExt.extract_ppg()
#
# print(extracted_ppg)
